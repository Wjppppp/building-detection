# %%
# %%bash
#
# # check cuda, cudnn, tensorflow
#
# nvidia-smi
# nvcc -V
# python -c "import tensorflow as tf;print('tensorflow version: ',tf.__version__)"
# Out:
# Tue May  2 15:24:47 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.104      Driver Version: 528.78       CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  On   | 00000000:01:00.0  On |                  N/A |
# | N/A   41C    P8    11W /  80W |    139MiB /  6144MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2021 NVIDIA Corporation
# Built on Sun_Feb_14_21:12:58_PST_2021
# Cuda compilation tools, release 11.2, V11.2.152
# Build cuda_11.2.r11.2/compiler.29618528_0
# tensorflow version:  2.6.2

# %% [markdown]
# #### Make sure you are working under `training_demo/`

# %% [markdown]
# ## Preparing the dataset
#
# Copy `train.record` and `valid.record` to `training_demo/annotations/`.

# %% [markdown]
# ## Training the model

# %%
# !python model_main_tf2.py --model_dir=models/my_ssd_resnet50_v1_fpn --pipeline_config_path=models/my_ssd_resnet50_v1_fpn/pipeline.config
# Out:
# 2023-05-02 14:41:32.187219: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:923] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-02 14:41:32.201048: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:923] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-02 14:41:32.201303: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:923] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-02 14:41:32.201873: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-02 14:41:32.203667: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:923] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-02 14:41:32.203894: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:923] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-02 14:41:32.204091: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:923] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-02 14:41:32.706177: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:923] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-02 14:41:32.706508: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:923] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-02 14:41:32.706536: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1594] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2023-05-02 14:41:32.706770: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:923] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-02 14:41:32.706831: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3443 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# I0502 14:41:32.875900 140009639151424 mirrored_strategy.py:369] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: None
# I0502 14:41:32.881797 140009639151424 config_util.py:552] Maybe overwriting train_steps: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0502 14:41:32.881915 140009639151424 config_util.py:552] Maybe overwriting use_bfloat16: False
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/object_detection/model_lib_v2.py:564: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# W0502 14:41:32.929635 140009639151424 deprecation.py:345] From /usr/local/lib/python3.6/dist-packages/object_detection/model_lib_v2.py:564: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# INFO:tensorflow:Reading unweighted datasets: ['annotations/train.record']
# I0502 14:41:32.942844 140009639151424 dataset_builder.py:162] Reading unweighted datasets: ['annotations/train.record']
# INFO:tensorflow:Reading record datasets for input file: ['annotations/train.record']
# I0502 14:41:32.943561 140009639151424 dataset_builder.py:79] Reading record datasets for input file: ['annotations/train.record']
# INFO:tensorflow:Number of filenames to read: 1
# I0502 14:41:32.943724 140009639151424 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W0502 14:41:32.943783 140009639151424 dataset_builder.py:87] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/object_detection/builders/dataset_builder.py:104: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.experimental_deterministic`.
# W0502 14:41:32.946310 140009639151424 deprecation.py:345] From /usr/local/lib/python3.6/dist-packages/object_detection/builders/dataset_builder.py:104: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.experimental_deterministic`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/object_detection/builders/dataset_builder.py:236: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W0502 14:41:32.965991 140009639151424 deprecation.py:345] From /usr/local/lib/python3.6/dist-packages/object_detection/builders/dataset_builder.py:236: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/util/dispatch.py:206: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W0502 14:41:38.550697 140009639151424 deprecation.py:345] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/util/dispatch.py:206: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/util/dispatch.py:206: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# W0502 14:41:40.972035 140009639151424 deprecation.py:345] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/util/dispatch.py:206: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/autograph/impl/api.py:464: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0502 14:41:42.280463 140009639151424 deprecation.py:345] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/autograph/impl/api.py:464: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# 2023-05-02 14:41:43.938358: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# /usr/local/lib/python3.6/dist-packages/keras/backend.py:401: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn('`tf.keras.backend.set_learning_phase` is deprecated and '
# I0502 14:41:48.662365 139999039166208 api.py:446] feature_map_spatial_dims: [(32, 32), (16, 16), (8, 8), (4, 4), (2, 2)]
# I0502 14:41:55.883528 139999039166208 api.py:446] feature_map_spatial_dims: [(32, 32), (16, 16), (8, 8), (4, 4), (2, 2)]
# 2023-05-02 14:42:00.964073: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8100
# 2023-05-02 14:42:03.172542: I tensorflow/stream_executor/cuda/cuda_blas.cc:1760] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0502 14:42:06.946472 140009639151424 cross_device_ops.py:621] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0502 14:42:06.947544 140009639151424 cross_device_ops.py:621] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0502 14:42:06.950130 140009639151424 cross_device_ops.py:621] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0502 14:42:06.951195 140009639151424 cross_device_ops.py:621] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0502 14:42:06.953549 140009639151424 cross_device_ops.py:621] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0502 14:42:06.954522 140009639151424 cross_device_ops.py:621] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0502 14:42:06.957330 140009639151424 cross_device_ops.py:621] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0502 14:42:06.958075 140009639151424 cross_device_ops.py:621] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0502 14:42:06.959462 140009639151424 cross_device_ops.py:621] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0502 14:42:06.960142 140009639151424 cross_device_ops.py:621] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/util/deprecation.py:617: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# W0502 14:42:08.111467 139999651538688 deprecation.py:548] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/util/deprecation.py:617: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# I0502 14:42:08.673645 139999651538688 api.py:446] feature_map_spatial_dims: [(32, 32), (16, 16), (8, 8), (4, 4), (2, 2)]
# I0502 14:42:12.125202 139999651538688 api.py:446] feature_map_spatial_dims: [(32, 32), (16, 16), (8, 8), (4, 4), (2, 2)]
# I0502 14:42:16.166159 139999651538688 api.py:446] feature_map_spatial_dims: [(32, 32), (16, 16), (8, 8), (4, 4), (2, 2)]
# I0502 14:42:20.208747 139999651538688 api.py:446] feature_map_spatial_dims: [(32, 32), (16, 16), (8, 8), (4, 4), (2, 2)]
# INFO:tensorflow:Step 100 per-step time 1.281s
# I0502 14:44:15.870119 140009639151424 model_lib_v2.py:707] Step 100 per-step time 1.281s
# INFO:tensorflow:{'Loss/classification_loss': 0.94322026,
#  'Loss/localization_loss': 1.1002283,
#  'Loss/regularization_loss': 2.0205162,
#  'Loss/total_loss': 4.063965,
#  'learning_rate': 0.014666351}
# I0502 14:44:15.870399 140009639151424 model_lib_v2.py:708] {'Loss/classification_loss': 0.94322026,
#  'Loss/localization_loss': 1.1002283,
#  'Loss/regularization_loss': 2.0205162,
#  'Loss/total_loss': 4.063965,
#  'learning_rate': 0.014666351}
# INFO:tensorflow:Step 200 per-step time 0.178s
# I0502 14:44:33.703622 140009639151424 model_lib_v2.py:707] Step 200 per-step time 0.178s
# INFO:tensorflow:{'Loss/classification_loss': 0.75856733,
#  'Loss/localization_loss': 1.1261551,
#  'Loss/regularization_loss': 2.0077899,
#  'Loss/total_loss': 3.8925123,
#  'learning_rate': 0.0159997}
# I0502 14:44:33.703895 140009639151424 model_lib_v2.py:708] {'Loss/classification_loss': 0.75856733,
#  'Loss/localization_loss': 1.1261551,
#  'Loss/regularization_loss': 2.0077899,
#  'Loss/total_loss': 3.8925123,
#  'learning_rate': 0.0159997}
# INFO:tensorflow:Step 300 per-step time 0.189s
# I0502 14:44:52.598652 140009639151424 model_lib_v2.py:707] Step 300 per-step time 0.189s
# INFO:tensorflow:{'Loss/classification_loss': 0.5318456,
#  'Loss/localization_loss': 1.0071678,
#  'Loss/regularization_loss': 1.9825295,
#  'Loss/total_loss': 3.521543,
#  'learning_rate': 0.01733305}
# I0502 14:44:52.598950 140009639151424 model_lib_v2.py:708] {'Loss/classification_loss': 0.5318456,
#  'Loss/localization_loss': 1.0071678,
#  'Loss/regularization_loss': 1.9825295,
#  'Loss/total_loss': 3.521543,
#  'learning_rate': 0.01733305}
# INFO:tensorflow:Step 400 per-step time 0.187s
# I0502 14:45:11.265305 140009639151424 model_lib_v2.py:707] Step 400 per-step time 0.187s
# INFO:tensorflow:{'Loss/classification_loss': 0.60394406,
#  'Loss/localization_loss': 1.0451462,
#  'Loss/regularization_loss': 1.9553925,
#  'Loss/total_loss': 3.6044827,
#  'learning_rate': 0.0186664}
# I0502 14:45:11.265559 140009639151424 model_lib_v2.py:708] {'Loss/classification_loss': 0.60394406,
#  'Loss/localization_loss': 1.0451462,
#  'Loss/regularization_loss': 1.9553925,
#  'Loss/total_loss': 3.6044827,
#  'learning_rate': 0.0186664}
# INFO:tensorflow:Step 500 per-step time 0.175s
# I0502 14:45:28.751023 140009639151424 model_lib_v2.py:707] Step 500 per-step time 0.175s
# INFO:tensorflow:{'Loss/classification_loss': 0.5257219,
#  'Loss/localization_loss': 0.6221553,
#  'Loss/regularization_loss': 1.927285,
#  'Loss/total_loss': 3.0751622,
#  'learning_rate': 0.01999975}
# I0502 14:45:28.751271 140009639151424 model_lib_v2.py:708] {'Loss/classification_loss': 0.5257219,
#  'Loss/localization_loss': 0.6221553,
#  'Loss/regularization_loss': 1.927285,
#  'Loss/total_loss': 3.0751622,
#  'learning_rate': 0.01999975}
# INFO:tensorflow:Step 600 per-step time 0.167s
# I0502 14:45:45.435859 140009639151424 model_lib_v2.py:707] Step 600 per-step time 0.167s
# INFO:tensorflow:{'Loss/classification_loss': 0.45782477,
#  'Loss/localization_loss': 0.79293585,
#  'Loss/regularization_loss': 1.897294,
#  'Loss/total_loss': 3.1480546,
#  'learning_rate': 0.0213331}
# I0502 14:45:45.436134 140009639151424 model_lib_v2.py:708] {'Loss/classification_loss': 0.45782477,
#  'Loss/localization_loss': 0.79293585,
#  'Loss/regularization_loss': 1.897294,
#  'Loss/total_loss': 3.1480546,
#  'learning_rate': 0.0213331}
# INFO:tensorflow:Step 700 per-step time 0.170s
# I0502 14:46:02.411175 140009639151424 model_lib_v2.py:707] Step 700 per-step time 0.170s
# INFO:tensorflow:{'Loss/classification_loss': 0.42063737,
#  'Loss/localization_loss': 0.5787723,
#  'Loss/regularization_loss': 1.8657023,
#  'Loss/total_loss': 2.8651118,
#  'learning_rate': 0.02266645}
# I0502 14:46:02.411416 140009639151424 model_lib_v2.py:708] {'Loss/classification_loss': 0.42063737,
#  'Loss/localization_loss': 0.5787723,
#  'Loss/regularization_loss': 1.8657023,
#  'Loss/total_loss': 2.8651118,
#  'learning_rate': 0.02266645}
# INFO:tensorflow:Step 800 per-step time 0.167s
# I0502 14:46:19.153196 140009639151424 model_lib_v2.py:707] Step 800 per-step time 0.167s
# INFO:tensorflow:{'Loss/classification_loss': 0.4420232,
#  'Loss/localization_loss': 1.0259894,
#  'Loss/regularization_loss': 1.8334954,
#  'Loss/total_loss': 3.301508,
#  'learning_rate': 0.023999799}
# I0502 14:46:19.153438 140009639151424 model_lib_v2.py:708] {'Loss/classification_loss': 0.4420232,
#  'Loss/localization_loss': 1.0259894,
#  'Loss/regularization_loss': 1.8334954,
#  'Loss/total_loss': 3.301508,
#  'learning_rate': 0.023999799}
# INFO:tensorflow:Step 900 per-step time 0.173s
# I0502 14:46:36.409441 140009639151424 model_lib_v2.py:707] Step 900 per-step time 0.173s
# INFO:tensorflow:{'Loss/classification_loss': 0.4328164,
#  'Loss/localization_loss': 0.9556709,
#  'Loss/regularization_loss': 1.7996109,
#  'Loss/total_loss': 3.1880982,
#  'learning_rate': 0.025333151}
# I0502 14:46:36.409695 140009639151424 model_lib_v2.py:708] {'Loss/classification_loss': 0.4328164,
#  'Loss/localization_loss': 0.9556709,
#  'Loss/regularization_loss': 1.7996109,
#  'Loss/total_loss': 3.1880982,
#  'learning_rate': 0.025333151}
# INFO:tensorflow:Step 1000 per-step time 0.177s
# I0502 14:46:54.142930 140009639151424 model_lib_v2.py:707] Step 1000 per-step time 0.177s
# INFO:tensorflow:{'Loss/classification_loss': 0.46693346,
#  'Loss/localization_loss': 0.55375916,
#  'Loss/regularization_loss': 1.7650534,
#  'Loss/total_loss': 2.785746,
#  'learning_rate': 0.0266665}
# I0502 14:46:54.143168 140009639151424 model_lib_v2.py:708] {'Loss/classification_loss': 0.46693346,
#  'Loss/localization_loss': 0.55375916,
#  'Loss/regularization_loss': 1.7650534,
#  'Loss/total_loss': 2.785746,
#  'learning_rate': 0.0266665}

# %%
# !tensorboard --logdir=models/my_ssd_resnet50_v1_fpn

# %% [markdown]
# ## Exporting a trained model

# %%
# !python exporter_main_v2.py --input_type image_tensor --pipeline_config_path models/my_ssd_resnet50_v1_fpn/pipeline.config --trained_checkpoint_dir models/my_ssd_resnet50_v1_fpn/ --output_directory exported-models/my_model
# Out:
# 2023-05-02 14:53:57.370863: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:923] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-02 14:53:57.377783: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:923] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-02 14:53:57.378013: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:923] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-02 14:53:57.388450: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-02 14:53:57.390627: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:923] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-02 14:53:57.390865: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:923] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-02 14:53:57.391009: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:923] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-02 14:53:57.934030: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:923] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-02 14:53:57.934264: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:923] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-02 14:53:57.934289: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1594] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2023-05-02 14:53:57.934600: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:923] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-02 14:53:57.934673: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3443 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/autograph/impl/api.py:463: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# W0502 14:53:58.374591 139931712935744 deprecation.py:616] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/autograph/impl/api.py:463: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# I0502 14:54:02.948184 139931712935744 api.py:446] feature_map_spatial_dims: [(32, 32), (16, 16), (8, 8), (4, 4), (2, 2)]
# I0502 14:54:11.823697 139931712935744 api.py:446] feature_map_spatial_dims: [(32, 32), (16, 16), (8, 8), (4, 4), (2, 2)]
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7f43601a2e48>, because it is not built.
# W0502 14:54:14.376336 139931712935744 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7f43601a2e48>, because it is not built.
# 2023-05-02 14:54:20.291115: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# I0502 14:54:20.972806 139931712935744 api.py:446] feature_map_spatial_dims: [(32, 32), (16, 16), (8, 8), (4, 4), (2, 2)]
# W0502 14:54:29.898748 139931712935744 save.py:254] Found untraced functions such as WeightSharedConvolutionalBoxPredictor_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxPredictor_layer_call_fn, WeightSharedConvolutionalBoxHead_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxHead_layer_call_fn, WeightSharedConvolutionalBoxPredictor_layer_call_fn while saving (showing 5 of 520). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: exported-models/my_model/saved_model/assets
# I0502 14:54:33.966327 139931712935744 builder_impl.py:781] Assets written to: exported-models/my_model/saved_model/assets
# INFO:tensorflow:Writing pipeline config file to exported-models/my_model/pipeline.config
# I0502 14:54:34.650923 139931712935744 config_util.py:254] Writing pipeline config file to exported-models/my_model/pipeline.config

# %%
# Out:
# Untitled.ipynb	exported-models      images		models
# annotations	exporter_main_v2.py  model_main_tf2.py	pre-trained-models

# %% [markdown]
# ## Inferencing
